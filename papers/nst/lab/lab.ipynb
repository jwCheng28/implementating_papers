# %%
# %cd implementating_papers/papers/nst/
# Out:
# /content/implementating_papers/papers/nst

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# !pip install -r requirements.txt

# %%
from src.stylize import run_nst

run_nst("images/content.jpg", "images/style.jpg")
# Out:
# Step [0/300] | Total Loss: 7749357389615294578688.0000 | Content: 0.0000 | Style: 7749357415694336.0000
# Step [1/300] | Total Loss: 6782583168406552313856.0000 | Content: 0.0516 | Style: 6782583362813952.0000
# Step [50/300] | Total Loss: 348716076500227457024.0000 | Content: 6.2973 | Style: 348716078727168.0000
# Step [100/300] | Total Loss: 116416317537201946624.0000 | Content: 8.0946 | Style: 116416313294848.0000
# Step [150/300] | Total Loss: 54072464527977349120.0000 | Content: 8.9113 | Style: 54072463851520.0000
# Step [200/300] | Total Loss: 29908231402530275328.0000 | Content: 9.4758 | Style: 29908231258112.0000
# Step [250/300] | Total Loss: 18565095505323360256.0000 | Content: 9.8889 | Style: 18565094703104.0000
# Stylized image saved.
